# %% [markdown]
# Advanced Dataframes Exercise Problems

# %%
import pandas as pd
import numpy as np
from env import host, user, password, get_db_url

# %% [markdown]
# Exercises Part 1

# %% [markdown]
# Problem 1 - 3

# %% [markdown]
# Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %%
def get_db_url_local(username, hostname, password, db_name):
    url = f'mysql+pymysql://{username}:{password}@{hostname}/{db_name}'
    return url

# %% [markdown]
# This is in the env.py file.

# %% [markdown]
# Problem 4: Use your function to obtain a connection to the employees database.

# %%
url = get_db_url(user, host, password, 'employees')

# %%
pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27

# %% [markdown]
# Problem 5:

# %% [markdown]
# a. Intentionally make a typo in the database url. What kind of error message do you see?

# %%
url = get_db_url(user, host, password, 'employs')

# %%
pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
# ...

# %% [markdown]
# Returns an access denied error

# %% [markdown]
# b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
url = get_db_url(user, host, password, 'employees')

# %%
pd.read_sql('SELECT * FROM employes LIMIT 5 OFFSET 50', url)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1770                 if not evt_handled:
# -> 1771                     self.dialect.do_execute(
#    1772                         cursor, statement, parameters, context
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
# ...

# %% [markdown]
# It access the database but since i mispelled the employees talbe in the query it lets me know the table does not exist.

# %% [markdown]
# Problem 6: Read the employees and titles tables into two separate DataFrames.

# %%
employees = pd.read_sql('SELECT * FROM employees', url)
employees
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
titles = pd.read_sql('SELECT * FROM titles', url)
titles
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %% [markdown]
# Problem 7: How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB

# %% [markdown]
# I have 300024 rows and 6 columns in the employees DataFrame.

# %%
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     443308 non-null  int64
#  1   title      443308 non-null  object
#  2   from_date  443308 non-null  object
#  3   to_date    443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB

# %% [markdown]
# I have 443308 rows and 4 columns in the titles DataFrame

# %% [markdown]
# Problem 8: Display the summary statistics for each DataFrame.

# %%
employees.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
titles.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %% [markdown]
# Problem 9: How many unique titles are in the titles DataFrame?

# %%
len(pd.read_sql('SELECT title FROM titles GROUP BY title', url))
# Out:
# 7

# %% [markdown]
# Problem 10: What is the oldest date in the to_date column?

# %%
pd.read_sql('SELECT to_date FROM titles', url).min()
# Out:
# to_date    1985-03-01
# dtype: object

# %% [markdown]
# Problem 11: What is the most recent date in the to_date column?

# %%
pd.read_sql('SELECT to_date FROM titles WHERE to_date != "9999-01-01"', url).max()
# Out:
# to_date    2002-08-01
# dtype: object

# %% [markdown]
# Exercise Part 2

# %% [markdown]
# Problem 1: Copy the users and roles DataFrames from the examples above.

# %%
# Create the users DataFrame.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# Problem 2: What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, how='right',left_on='id',right_on='id')
# Out:
#    id name_x  role_id     name_y
# 0   1    bob      1.0      admin
# 1   2    joe      2.0     author
# 2   3  sally      3.0   reviewer
# 3   4   adam      3.0  commenter

# %% [markdown]
# Problem 3: What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, how='outer',left_on='id',right_on='id')
# Out:
#    id name_x  role_id     name_y
# 0   1    bob      1.0      admin
# 1   2    joe      2.0     author
# 2   3  sally      3.0   reviewer
# 3   4   adam      3.0  commenter
# 4   5   jane      NaN        NaN
# 5   6   mike      NaN        NaN

# %% [markdown]
# Problem 4: What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
users.merge(roles, how='right')
# Out:
#    id       name  role_id
# 0   1      admin      NaN
# 1   2     author      NaN
# 2   3   reviewer      NaN
# 3   4  commenter      NaN

# %% [markdown]
# Dropping both keys resutls in just the roles DataFrame with an extra NaN role_id column

# %%
users.merge(roles, how='right',left_on='id')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# /var/folders/lg/ftvnw2s97_z5h66qcl3vwwf00000gn/T/ipykernel_1071/3953285908.py in <module>
# ----> 1 users.merge(roles, how='right',left_on='id')
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9188         from pandas.core.reshape.merge import merge
#    9189
# -> 9190         return merge(
#    9191             self,
#    9192             right,
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
# ...

# %% [markdown]
# Dropping both results in an error. "Must Pass "right_on" OR "right_index"

# %% [markdown]
# Problem 5: Load the mpg dataset from PyDataset.

# %%
from pydataset import data
mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# Problem 6: Output and read the documentation for the mpg dataset.

# %%
data('mpg',show_doc = True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# Problem 7: How many rows and columns are in the dataset?

# %% [markdown]
# According to the documentation there are 234 rows and 11 columns

# %%
mpg.shape
# Out:
# (234, 11)

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %% [markdown]
# Shape and info() are other ways of getting more information on the DataFrame

# %% [markdown]
# Problem 8: Check out your column names and perform any cleanup you may want on them.

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg = mpg.rename(columns={'displ':'engine displacement',
                          'cyl':'cylinders',
                          'trans':'transmission',
                          'cty':'city','hwy':'highway'})
mpg
# Out:
#     manufacturer   model  engine displacement  year  cylinders transmission  \
# 1           audi      a4                  1.8  1999          4     auto(l5)
# 2           audi      a4                  1.8  1999          4   manual(m5)
# 3           audi      a4                  2.0  2008          4   manual(m6)
# 4           audi      a4                  2.0  2008          4     auto(av)
# 5           audi      a4                  2.8  1999          6     auto(l5)
# ..           ...     ...                  ...   ...        ...          ...
# 230   volkswagen  passat                  2.0  2008          4     auto(s6)
# 231   volkswagen  passat                  2.0  2008          4   manual(m6)
# 232   volkswagen  passat                  2.8  1999          6     auto(l5)
# 233   volkswagen  passat                  2.8  1999          6   manual(m5)
# 234   volkswagen  passat                  3.6  2008          6     auto(s6)
#
#     drv  city  highway fl    class
# ...

# %% [markdown]
# Problem 9: Display the summary statistics for the dataset.

# %%
mpg.describe()
# Out:
#        engine displacement         year   cylinders        city     highway
# count           234.000000   234.000000  234.000000  234.000000  234.000000
# mean              3.471795  2003.500000    5.888889   16.858974   23.440171
# std               1.291959     4.509646    1.611534    4.255946    5.954643
# min               1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%               2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%               3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%               4.600000  2008.000000    8.000000   19.000000   27.000000
# max               7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# Problem 10: How many different manufacturers are there?

# %%
len(mpg.groupby('manufacturer'))
# Out:
# 15

# %% [markdown]
# Problem 11: How many different models are there?

# %%
len(mpg.groupby('model'))
# Out:
# 38

# %% [markdown]
# Problem 12: Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['milage_difference'] = mpg.highway - mpg.city
mpg
# Out:
#     manufacturer   model  engine displacement  year  cylinders transmission  \
# 1           audi      a4                  1.8  1999          4     auto(l5)
# 2           audi      a4                  1.8  1999          4   manual(m5)
# 3           audi      a4                  2.0  2008          4   manual(m6)
# 4           audi      a4                  2.0  2008          4     auto(av)
# 5           audi      a4                  2.8  1999          6     auto(l5)
# ..           ...     ...                  ...   ...        ...          ...
# 230   volkswagen  passat                  2.0  2008          4     auto(s6)
# 231   volkswagen  passat                  2.0  2008          4   manual(m6)
# 232   volkswagen  passat                  2.8  1999          6     auto(l5)
# 233   volkswagen  passat                  2.8  1999          6   manual(m5)
# 234   volkswagen  passat                  3.6  2008          6     auto(s6)
#
#     drv  city  highway fl    class  milage_difference
# ...

# %% [markdown]
# Problem 13: Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = mpg[['city','highway']].mean(axis=1)
mpg
# Out:
#     manufacturer   model  engine displacement  year  cylinders transmission  \
# 1           audi      a4                  1.8  1999          4     auto(l5)
# 2           audi      a4                  1.8  1999          4   manual(m5)
# 3           audi      a4                  2.0  2008          4   manual(m6)
# 4           audi      a4                  2.0  2008          4     auto(av)
# 5           audi      a4                  2.8  1999          6     auto(l5)
# ..           ...     ...                  ...   ...        ...          ...
# 230   volkswagen  passat                  2.0  2008          4     auto(s6)
# 231   volkswagen  passat                  2.0  2008          4   manual(m6)
# 232   volkswagen  passat                  2.8  1999          6     auto(l5)
# 233   volkswagen  passat                  2.8  1999          6   manual(m5)
# 234   volkswagen  passat                  3.6  2008          6     auto(s6)
#
# ...

# %% [markdown]
# Problem 14: Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg['is_automatic'] = mpg.transmission.str.contains('auto')
mpg
# Out:
#     manufacturer   model  engine displacement  year  cylinders transmission  \
# 1           audi      a4                  1.8  1999          4     auto(l5)
# 2           audi      a4                  1.8  1999          4   manual(m5)
# 3           audi      a4                  2.0  2008          4   manual(m6)
# 4           audi      a4                  2.0  2008          4     auto(av)
# 5           audi      a4                  2.8  1999          6     auto(l5)
# ..           ...     ...                  ...   ...        ...          ...
# 230   volkswagen  passat                  2.0  2008          4     auto(s6)
# 231   volkswagen  passat                  2.0  2008          4   manual(m6)
# 232   volkswagen  passat                  2.8  1999          6     auto(l5)
# 233   volkswagen  passat                  2.8  1999          6   manual(m5)
# 234   volkswagen  passat                  3.6  2008          6     auto(s6)
#
# ...

# %% [markdown]
# Problem 15: Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg.groupby('manufacturer').average_mileage.agg('mean').sort_values(ascending=False).head(1)
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %% [markdown]
# Problem 16: Do automatic or manual cars have better miles per gallon?

# %%
mpg.groupby('is_automatic').average_mileage.agg('mean')
# Out:
# is_automatic
# False    22.227273
# True     19.130573
# Name: average_mileage, dtype: float64

# %%
mpg.groupby('is_automatic')[['city','highway','average_mileage']].mean().sort_values(by= 'is_automatic',ascending=False)
# Out:
#                    city    highway  average_mileage
# is_automatic
# True          15.968153  22.292994        19.130573
# False         18.675325  25.779221        22.227273

# %%
mpg['Transmission_cat'] = np.where(mpg.transmission.str.contains('auto'),'auto','manual')

# %%
mpg.groupby('Transmission_cat').average_mileage.agg('mean')
# Out:
# Transmission_cat
# auto      19.130573
# manual    22.227273
# Name: average_mileage, dtype: float64

# %% [markdown]
# Looks better

# %% [markdown]
# Manual cars have a better overall average mileage.

# %% [markdown]
# Exercises Part 3

# %% [markdown]
# Problem 1: Use your get_db_url function to help you explore the data from the chipotle database.

# %%
url = get_db_url('chipotle')
orders = pd.read_sql('SELECT * FROM orders',url,index_col='id')
orders
# Out:
#       order_id  quantity                              item_name  \
# id
# 1            1         1           Chips and Fresh Tomato Salsa
# 2            1         1                                   Izze
# 3            1         1                       Nantucket Nectar
# 4            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4618      1833         1                          Steak Burrito
# 4619      1833         1                          Steak Burrito
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
# 4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# id
# 1                                                                                   nan
# ...

# %%
orders.info()
orders
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4622 entries, 1 to 4622
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  4622 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 216.7+ KB

# %% [markdown]
# Problem 2: What is the total price for each order?

# %%
orders['item_price'] = orders['item_price'].str.replace('$','', regex =False).str.replace(',','', regex=False).astype('float')
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4622 entries, 1 to 4622
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  4622 non-null   object
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 216.7+ KB

# %%
orders.groupby('order_id').item_price.agg('sum')
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %% [markdown]
# Problem 3: What are the most popular 3 items?

# %%
orders.groupby('item_name').quantity.agg('sum').sort_values(ascending=False).head(3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %% [markdown]
# Problem 4: Which item has produced the most revenue?

# %%
orders.groupby('item_name').item_price.agg('sum').sort_values(ascending=False).head(1)
# Out:
# item_name
# Chicken Bowl    7342.73
# Name: item_price, dtype: float64

# %% [markdown]
# Problem 5: Join the employees and titles DataFrames together.

# %%
url = get_db_url('employees')
employees = pd.read_sql('DESCRIBE employees', url)
titles = pd.read_sql('Describe titles', url)
emp_titles = pd.read_sql('SELECT * FROM employees e INNER JOIN titles t ON e.emp_no = t.emp_no', url)

# %%
employees
# Out:
#         Field           Type Null  Key Default Extra
# 0      emp_no            int   NO  PRI    None
# 1  birth_date           date   NO         None
# 2  first_name    varchar(14)   NO         None
# 3   last_name    varchar(16)   NO         None
# 4      gender  enum('M','F')   NO         None
# 5   hire_date           date   NO         None

# %%
titles
# Out:
#        Field         Type Null  Key Default Extra
# 0     emp_no          int   NO  PRI    None
# 1      title  varchar(50)   NO  PRI    None
# 2  from_date         date   NO  PRI    None
# 3    to_date         date  YES         None

# %%
emp_titles
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  emp_no  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26   10001
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21   10002
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28   10003
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01   10004
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01   10004
# ...        ...         ...        ...       ...    ...         ...     ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21  499997
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21  499997
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13  499998
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13  499998
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30  499999
#
#                   title   from_date     to_date
# ...

# %% [markdown]
# I get the emp_no column twice so I will try a merge.

# %%
url = get_db_url('employees')
employees = pd.read_sql('SELECT * FROM employees', url)
titles = pd.read_sql('SELECT * FROM titles', url)

# %%
employees
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
titles
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
emp_titles = employees.merge(titles, how='inner', on= 'emp_no')
emp_titles
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# ...

# %% [markdown]
# Problem 6: For each title, find the hire date of the employee that was hired most recently with that title.

# %%
emp_titles.groupby('title').hire_date.agg('max')
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %% [markdown]
# Problem 7: Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
pd.read_sql('SHOW TABLES',url)
# Out:
#   Tables_in_employees
# 0         departments
# 1            dept_emp
# 2        dept_manager
# 3           employees
# 4            salaries
# 5              titles

# %%
dep_titles = pd.read_sql('''SELECT * FROM departments d 
                                        Join dept_emp de 
                                            ON d.dept_no = de.dept_no 
                                        JOIN titles t 
                                            ON de.emp_no = t.emp_no''', url)
dep_titles
# Out:
#        dept_no         dept_name  emp_no dept_no   from_date     to_date  \
# 0         d009  Customer Service   10011    d009  1990-01-22  1996-11-09
# 1         d009  Customer Service   10038    d009  1989-09-20  9999-01-01
# 2         d009  Customer Service   10038    d009  1989-09-20  9999-01-01
# 3         d009  Customer Service   10049    d009  1992-05-04  9999-01-01
# 4         d009  Customer Service   10049    d009  1992-05-04  9999-01-01
# ...        ...               ...     ...     ...         ...         ...
# 489898    d007             Sales  499986    d007  1985-08-11  9999-01-01
# 489899    d007             Sales  499986    d007  1985-08-11  9999-01-01
# 489900    d007             Sales  499987    d007  1999-12-21  9999-01-01
# 489901    d007             Sales  499988    d007  1988-07-25  2001-10-09
# 489902    d007             Sales  499988    d007  1988-07-25  2001-10-09
#
#         emp_no         title   from_date     to_date
# ...

# %%
pd.crosstab(dep_titles.dept_name, dep_titles.title)
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                   298      2362        4             2027
# Development                       7769     58135        2            49326
# Finance                              0         0        2                0
# Human Resources                      0         0        2                0
# Marketing                            0         0        2                0
# Production                        6445     49649        4            42205
# Quality Management                1831     13852        4            11864
# Research                           378      2986        2             2570
# Sales                                0         0        2                0
#
# title               Senior Staff  Staff  Technique Leader
# dept_name
# Customer Service           13925  16150               309
# Development                 1247   1424              7683
# ...
